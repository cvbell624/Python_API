# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import seaborn as sns

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 612

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count = 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        if (response.status_code == 200):
            # Extract data
            city_weather = response.json()

            # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
            city_name = city_weather.get("name")
            city_country = city_weather.get("sys", {}).get("country")
            city_date = city_weather.get("dt")
            city_humidity = city_weather.get("main", {}).get("humidity")
            city_max_temp = city_weather.get("main", {}).get("temp_max")
            city_clouds = city_weather.get("clouds", {}).get("all")
            city_wind = city_weather.get("wind", {}).get("speed")
    
            city_lat = city_weather.get("coord", {}).get("lat")
            city_lng = city_weather.get("coord", {}).get("lon")

            # Append the City information into city_data list
            city_data.append({"City": city_name,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date})
        else:
            print(f"YO! The API threw a non-200 status code: {response['status_code']} for city {city}") # error log
            print()
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 1 of Set 1 | olonkinbyen
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 1 of Set 1 | fale old settlement
# Processing Record 1 of Set 1 | grytviken
# Processing Record 1 of Set 1 | kodiak
# Processing Record 1 of Set 1 | haiku-pauwela
# Processing Record 1 of Set 1 | ironwood
# Processing Record 1 of Set 1 | edinburgh of the seven seas
# Processing Record 1 of Set 1 | bethel
# Processing Record 1 of Set 1 | thompson
# Processing Record 1 of Set 1 | vadso
# Processing Record 1 of Set 1 | ust-nera
# Processing Record 1 of Set 1 | luderitz
# Processing Record 1 of Set 1 | west island
# Processing Record 1 of Set 1 | sari
# Processing Record 1 of Set 1 | sitka
# Processing Record 1 of Set 1 | bento goncalves
# Processing Record 1 of Set 1 | tarawa
# Processing Record 1 of Set 1 | alice springs
# Processing Record 1 of Set 1 | khandyga
# Processing Record 1 of Set 1 | zeya
# Processing Record 1 of Set 1 | bu'aale
# Processing Record 1 of Set 1 | gadzhiyevo
# Processing Record 1 of Set 1 | margaret river
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 1 of Set 1 | cruz
# Processing Record 1 of Set 1 | aasiaat
# Processing Record 1 of Set 1 | baghlan
# Processing Record 1 of Set 1 | nuuk
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 1 of Set 1 | douentza
# Processing Record 1 of Set 1 | perryton
# Processing Record 1 of Set 1 | adamstown
# Processing Record 1 of Set 1 | tazacorte
# Processing Record 1 of Set 1 | klyuchi
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 1 of Set 1 | cill airne
# Processing Record 1 of Set 1 | pontianak
# Processing Record 1 of Set 1 | swakopmund
# Processing Record 1 of Set 1 | leava
# Processing Record 1 of Set 1 | hermanus
# Processing Record 1 of Set 1 | posto fiscal rolim de moura
# Processing Record 1 of Set 1 | nova sintra
# Processing Record 1 of Set 1 | avarua
# Processing Record 1 of Set 1 | kerikeri
# Processing Record 1 of Set 1 | waitangi
# Processing Record 1 of Set 1 | korla
# Processing Record 1 of Set 1 | udachny
# Processing Record 0 of Set 2 | moranbah
# Processing Record 1 of Set 2 | ilulissat
# Processing Record 1 of Set 2 | hasaki
# Processing Record 1 of Set 2 | sao goncalo do amarante
# Processing Record 1 of Set 2 | botou
# Processing Record 1 of Set 2 | invercargill
# Processing Record 1 of Set 2 | iskateley
# Processing Record 1 of Set 2 | college
# Processing Record 1 of Set 2 | tsiombe
# Processing Record 1 of Set 2 | afaahiti
# Processing Record 1 of Set 2 | shortandy
# Processing Record 1 of Set 2 | sandnessjoen
# Processing Record 1 of Set 2 | saltpond
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 1 of Set 2 | talnakh
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 1 of Set 2 | caconda
# Processing Record 1 of Set 2 | shenandoah
# Processing Record 1 of Set 2 | puerto baquerizo moreno
# Processing Record 1 of Set 2 | georgetown
# Processing Record 1 of Set 2 | sangmelima
# Processing Record 1 of Set 2 | kununurra
# Processing Record 1 of Set 2 | al jawf
# Processing Record 1 of Set 2 | kikwit
# Processing Record 1 of Set 2 | kailua-kona
# Processing Record 1 of Set 2 | lyubim
# Processing Record 1 of Set 2 | carutapera
# Processing Record 1 of Set 2 | island harbour
# Processing Record 1 of Set 2 | villazon
# Processing Record 1 of Set 2 | fisterra
# Processing Record 1 of Set 2 | palmer
# Processing Record 1 of Set 2 | iquique
# Processing Record 1 of Set 2 | isafjordur
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 1 of Set 2 | sandy
# Processing Record 1 of Set 2 | perevolotskiy
# Processing Record 1 of Set 2 | saipan
# Processing Record 1 of Set 2 | hawaiian paradise park
# Processing Record 1 of Set 2 | anadyr
# Processing Record 1 of Set 2 | saldanha
# Processing Record 1 of Set 2 | maisi
# Processing Record 1 of Set 2 | barra de santo antonio
# Processing Record 1 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 1 of Set 2 | minas de marcona
# Processing Record 1 of Set 2 | pundong
# Processing Record 1 of Set 2 | mont-dore
# Processing Record 1 of Set 2 | hamilton
# Processing Record 1 of Set 2 | tateyama
# Processing Record 1 of Set 2 | farim
# Processing Record 1 of Set 2 | coquimbo
# Processing Record 0 of Set 3 | qaqortoq
# Processing Record 1 of Set 3 | tiksi
# Processing Record 1 of Set 3 | gaalkacyo
# Processing Record 1 of Set 3 | naze
# Processing Record 1 of Set 3 | blackmans bay
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 1 of Set 3 | ubari
# Processing Record 1 of Set 3 | stanley
# Processing Record 1 of Set 3 | youkounkoun
# Processing Record 1 of Set 3 | colonia
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 1 of Set 3 | albany
# Processing Record 1 of Set 3 | saint-francois
# Processing Record 1 of Set 3 | wailua homesteads
# Processing Record 1 of Set 3 | puerto ayora
# Processing Record 1 of Set 3 | hotan
# Processing Record 1 of Set 3 | mount isa
# Processing Record 1 of Set 3 | chonchi
# Processing Record 1 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 1 of Set 3 | pont rouge
# Processing Record 1 of Set 3 | mili
# Processing Record 1 of Set 3 | badger
# Processing Record 1 of Set 3 | kalmunai
# Processing Record 1 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 1 of Set 3 | yuzhno-kurilsk
# Processing Record 1 of Set 3 | itaituba
# Processing Record 1 of Set 3 | constantia
# Processing Record 1 of Set 3 | angaur state
# Processing Record 1 of Set 3 | lompoc
# Processing Record 1 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 3 | berdigestyakh
# Processing Record 1 of Set 3 | tura
# Processing Record 1 of Set 3 | koprubasi
# Processing Record 1 of Set 3 | vila do maio
# Processing Record 1 of Set 3 | praia da vitoria
# Processing Record 1 of Set 3 | utrik
# Processing Record 1 of Set 3 | buenos aires
# Processing Record 1 of Set 3 | namsos
# Processing Record 1 of Set 3 | namibe
# Processing Record 1 of Set 3 | nagqu
# Processing Record 1 of Set 3 | neiafu
# Processing Record 1 of Set 3 | ghat
# Processing Record 1 of Set 3 | fortuna
# Processing Record 1 of Set 3 | kolwezi
# Processing Record 1 of Set 3 | vorkuta
# Processing Record 1 of Set 3 | quezon
# Processing Record 1 of Set 3 | saint-leu
# Processing Record 1 of Set 3 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 1 of Set 3 | nizhniy odes
# Processing Record 1 of Set 3 | walvis bay
# Processing Record 0 of Set 4 | takamaka
# City not found. Skipping...
# Processing Record 1 of Set 4 | jamestown
# Processing Record 1 of Set 4 | northam
# Processing Record 1 of Set 4 | dudinka
# Processing Record 1 of Set 4 | homer
# Processing Record 1 of Set 4 | tabou
# Processing Record 1 of Set 4 | kirensk
# Processing Record 1 of Set 4 | strelka
# Processing Record 1 of Set 4 | tazovsky
# Processing Record 1 of Set 4 | lishui
# Processing Record 1 of Set 4 | cockburn town
# Processing Record 1 of Set 4 | tuburan
# Processing Record 1 of Set 4 | kingston
# Processing Record 1 of Set 4 | aykhal
# Processing Record 1 of Set 4 | ouellah
# City not found. Skipping...
# Processing Record 1 of Set 4 | talovskiy
# Processing Record 1 of Set 4 | lebu
# Processing Record 1 of Set 4 | yongbyon
# Processing Record 1 of Set 4 | beau vallon
# Processing Record 1 of Set 4 | vozhega
# Processing Record 1 of Set 4 | bektemir
# Processing Record 1 of Set 4 | greymouth
# Processing Record 1 of Set 4 | rundu
# Processing Record 1 of Set 4 | palasa
# Processing Record 1 of Set 4 | papatowai
# Processing Record 1 of Set 4 | ola
# Processing Record 1 of Set 4 | amga
# Processing Record 1 of Set 4 | nar'yan-mar
# Processing Record 1 of Set 4 | sal'sk
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 1 of Set 4 | talcahuano
# Processing Record 1 of Set 4 | susuman
# Processing Record 1 of Set 4 | corbeni
# Processing Record 1 of Set 4 | tera
# Processing Record 1 of Set 4 | tamazunchale
# Processing Record 1 of Set 4 | bilibino
# Processing Record 1 of Set 4 | san julian
# Processing Record 1 of Set 4 | baikonur
# Processing Record 1 of Set 4 | lospalos
# Processing Record 1 of Set 4 | machico
# Processing Record 1 of Set 4 | dryden
# Processing Record 1 of Set 4 | tromso
# Processing Record 1 of Set 4 | polyarnyy
# Processing Record 1 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 1 of Set 4 | mossel bay
# Processing Record 1 of Set 4 | howard springs
# Processing Record 1 of Set 4 | peraiyur
# Processing Record 1 of Set 4 | bontang
# Processing Record 1 of Set 4 | laojunmiao
# Processing Record 1 of Set 4 | noumea
# Processing Record 0 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 1 of Set 5 | jarash
# Processing Record 1 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 1 of Set 5 | sadjoavato
# Processing Record 1 of Set 5 | san agustin de valle fertil
# Processing Record 1 of Set 5 | siwa oasis
# Processing Record 1 of Set 5 | yangor
# City not found. Skipping...
# Processing Record 1 of Set 5 | vitoria da conquista
# Processing Record 1 of Set 5 | sao joao da barra
# Processing Record 1 of Set 5 | port mathurin
# Processing Record 1 of Set 5 | yershov
# Processing Record 1 of Set 5 | chiang klang
# Processing Record 1 of Set 5 | illizi
# Processing Record 1 of Set 5 | novyy urgal
# Processing Record 1 of Set 5 | atafu village
# Processing Record 1 of Set 5 | hadibu
# Processing Record 1 of Set 5 | east london
# Processing Record 1 of Set 5 | hashtrud
# Processing Record 1 of Set 5 | guerrero negro
# Processing Record 1 of Set 5 | lihue
# Processing Record 1 of Set 5 | toliara
# Processing Record 1 of Set 5 | vorgashor
# Processing Record 1 of Set 5 | ad dabbah
# Processing Record 1 of Set 5 | magadan
# Processing Record 1 of Set 5 | viransehir
# Processing Record 1 of Set 5 | bocana de paiwas
# Processing Record 1 of Set 5 | port-vila
# Processing Record 1 of Set 5 | sibolga
# Processing Record 1 of Set 5 | khovd
# Processing Record 1 of Set 5 | uray
# Processing Record 1 of Set 5 | savanna-la-mar
# Processing Record 1 of Set 5 | hami
# Processing Record 1 of Set 5 | port lincoln
# Processing Record 1 of Set 5 | brokopondo
# Processing Record 1 of Set 5 | am djarass
# City not found. Skipping...
# Processing Record 1 of Set 5 | stepnogorsk
# Processing Record 1 of Set 5 | la passe
# Processing Record 1 of Set 5 | namdrik
# Processing Record 1 of Set 5 | eyl
# Processing Record 1 of Set 5 | kratie
# Processing Record 1 of Set 5 | cadale
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 1 of Set 5 | zakynthos
# Processing Record 1 of Set 5 | bergen auf rugen
# City not found. Skipping...
# Processing Record 1 of Set 5 | nenjiang
# Processing Record 1 of Set 5 | tobelo
# Processing Record 1 of Set 5 | san jose village
# City not found. Skipping...
# Processing Record 1 of Set 5 | prince george
# Processing Record 1 of Set 5 | kogalym
# Processing Record 1 of Set 5 | nikolayevsk-on-amure
# Processing Record 0 of Set 6 | alaghsas
# Processing Record 1 of Set 6 | slave lake
# Processing Record 1 of Set 6 | kulhudhuffushi
# Processing Record 1 of Set 6 | mikhaylovskoye
# Processing Record 1 of Set 6 | inirida
# Processing Record 1 of Set 6 | port shepstone
# Processing Record 1 of Set 6 | tadine
# Processing Record 1 of Set 6 | palau
# Processing Record 1 of Set 6 | margate
# Processing Record 1 of Set 6 | shangri-la
# City not found. Skipping...
# Processing Record 1 of Set 6 | alcacer do sal
# Processing Record 1 of Set 6 | san patricio
# Processing Record 1 of Set 6 | peace river
# Processing Record 1 of Set 6 | inari
# Processing Record 1 of Set 6 | panambi
# Processing Record 1 of Set 6 | taoudenni
# Processing Record 1 of Set 6 | kill devil hills
# Processing Record 1 of Set 6 | inhambane
# Processing Record 1 of Set 6 | pacific grove
# Processing Record 1 of Set 6 | enewetak
# Processing Record 1 of Set 6 | salinas
# Processing Record 1 of Set 6 | weno
# Processing Record 1 of Set 6 | pointe aux piments
# Processing Record 1 of Set 6 | bechar
# Processing Record 1 of Set 6 | san luis de la loma
# Processing Record 1 of Set 6 | midvagur
# Processing Record 1 of Set 6 | sinabang
# Processing Record 1 of Set 6 | nemuro
# Processing Record 1 of Set 6 | novokuznetsk
# Processing Record 1 of Set 6 | mahina
# Processing Record 1 of Set 6 | marudi
# City not found. Skipping...
# Processing Record 1 of Set 6 | tanjung selor
# Processing Record 1 of Set 6 | itoman
# Processing Record 1 of Set 6 | santa ana de yacuma
# Processing Record 1 of Set 6 | stornoway
# Processing Record 1 of Set 6 | mysen
# Processing Record 1 of Set 6 | quiberon
# Processing Record 1 of Set 6 | dzhambeyty
# Processing Record 1 of Set 6 | don luan
# Processing Record 1 of Set 6 | boguchany
# Processing Record 1 of Set 6 | taltal
# Processing Record 1 of Set 6 | castillos
# Processing Record 1 of Set 6 | camana
# Processing Record 1 of Set 6 | katsuura
# Processing Record 1 of Set 6 | okhotsk
# Processing Record 1 of Set 6 | nuku'alofa
# Processing Record 1 of Set 6 | shingu
# Processing Record 1 of Set 6 | piti village
# Processing Record 1 of Set 6 | tolanaro
# Processing Record 1 of Set 6 | cromwell
# Processing Record 0 of Set 7 | pisco
# Processing Record 1 of Set 7 | batouri
# Processing Record 1 of Set 7 | prieska
# Processing Record 1 of Set 7 | peniscola
# Processing Record 1 of Set 7 | labrador city
# Processing Record 1 of Set 7 | maubara
# City not found. Skipping...
# Processing Record 1 of Set 7 | qamdo
# Processing Record 1 of Set 7 | new norfolk
# Processing Record 1 of Set 7 | olyokminsk
# Processing Record 1 of Set 7 | kirakira
# Processing Record 1 of Set 7 | karratha
# Processing Record 1 of Set 7 | berezovyy
# Processing Record 1 of Set 7 | civril
# Processing Record 1 of Set 7 | st. john's
# Processing Record 1 of Set 7 | kiunga
# Processing Record 1 of Set 7 | calbuco
# Processing Record 1 of Set 7 | labytnangi
# Processing Record 1 of Set 7 | aldinga beach
# Processing Record 1 of Set 7 | vilyuysk
# Processing Record 1 of Set 7 | khadyzhensk
# Processing Record 1 of Set 7 | gorodoviki
# Processing Record 1 of Set 7 | rio grande
# Processing Record 1 of Set 7 | kamen'-na-obi
# Processing Record 1 of Set 7 | queenstown
# Processing Record 1 of Set 7 | rahim yar khan
# City not found. Skipping...
# Processing Record 1 of Set 7 | usogorsk
# Processing Record 1 of Set 7 | cidreira
# Processing Record 1 of Set 7 | lalganj
# Processing Record 1 of Set 7 | saint-florent-sur-cher
# Processing Record 1 of Set 7 | yenotayevka
# Processing Record 1 of Set 7 | vilyuchinsk
# Processing Record 1 of Set 7 | soata
# Processing Record 1 of Set 7 | wakkanai
# Processing Record 1 of Set 7 | yeraliyev
# Processing Record 1 of Set 7 | bandundu
# Processing Record 1 of Set 7 | gamba
# Processing Record 1 of Set 7 | puerto francisco de orellana
# Processing Record 1 of Set 7 | lazaro cardenas
# Processing Record 1 of Set 7 | qapqal
# City not found. Skipping...
# Processing Record 1 of Set 7 | barah
# Processing Record 1 of Set 7 | tarimoro
# Processing Record 1 of Set 7 | phillip island
# Processing Record 1 of Set 7 | kangiwa
# Processing Record 1 of Set 7 | zapadnaya dvina
# Processing Record 1 of Set 7 | majuro
# Processing Record 1 of Set 7 | shilka
# Processing Record 1 of Set 7 | whyalla stuart
# City not found. Skipping...
# Processing Record 1 of Set 7 | tolmezzo
# Processing Record 1 of Set 7 | gornji petrovci
# Processing Record 1 of Set 7 | sept-iles
# Processing Record 0 of Set 8 | mount gambier
# Processing Record 1 of Set 8 | nanakuli
# Processing Record 1 of Set 8 | ilhabela
# Processing Record 1 of Set 8 | madinat ash shamal
# Processing Record 1 of Set 8 | onega
# Processing Record 1 of Set 8 | usinsk
# Processing Record 1 of Set 8 | bulnes
# Processing Record 1 of Set 8 | acarau
# Processing Record 1 of Set 8 | tofol
# Processing Record 1 of Set 8 | punta arenas
# Processing Record 1 of Set 8 | broome
# Processing Record 1 of Set 8 | uturoa
# Processing Record 1 of Set 8 | bardai
# Processing Record 1 of Set 8 | candolim
# Processing Record 1 of Set 8 | palikir - national government center
# Processing Record 1 of Set 8 | saint-pierre
# Processing Record 1 of Set 8 | ash shatrah
# Processing Record 1 of Set 8 | chibougamau
# Processing Record 1 of Set 8 | volda
# Processing Record 1 of Set 8 | dhuusamarreeb
# Processing Record 1 of Set 8 | pandan
# Processing Record 1 of Set 8 | pastos bons
# Processing Record 1 of Set 8 | fano
# Processing Record 1 of Set 8 | tallahassee
# Processing Record 1 of Set 8 | vicuna
# Processing Record 1 of Set 8 | yanchep
# Processing Record 1 of Set 8 | lashio
# Processing Record 1 of Set 8 | whitehorse
# Processing Record 1 of Set 8 | kavieng
# Processing Record 1 of Set 8 | myeik
# Processing Record 1 of Set 8 | la sarre
# Processing Record 1 of Set 8 | kushk
# Processing Record 1 of Set 8 | ta`u
# Processing Record 1 of Set 8 | eureka
# Processing Record 1 of Set 8 | litomerice
# Processing Record 1 of Set 8 | uliastay
# Processing Record 1 of Set 8 | gafsa
# Processing Record 1 of Set 8 | katsuren-haebaru
# Processing Record 1 of Set 8 | dila
# Processing Record 1 of Set 8 | red deer
# Processing Record 1 of Set 8 | loughrea
# Processing Record 1 of Set 8 | crane
# Processing Record 1 of Set 8 | itarare
# Processing Record 1 of Set 8 | pemangkat
# Processing Record 1 of Set 8 | villiers
# Processing Record 1 of Set 8 | luang prabang
# Processing Record 1 of Set 8 | san antonio
# Processing Record 1 of Set 8 | kutum
# Processing Record 1 of Set 8 | muscat
# Processing Record 1 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 0 of Set 9 | prince rupert
# Processing Record 1 of Set 9 | bubaque
# Processing Record 1 of Set 9 | nadi
# Processing Record 1 of Set 9 | ishinomaki
# Processing Record 1 of Set 9 | chernyshevskiy
# Processing Record 1 of Set 9 | acapulco de juarez
# Processing Record 1 of Set 9 | calderitas
# Processing Record 1 of Set 9 | bodo
# Processing Record 1 of Set 9 | keflavik
# Processing Record 1 of Set 9 | zhangye
# Processing Record 1 of Set 9 | monywa
# Processing Record 1 of Set 9 | sihanoukville
# Processing Record 1 of Set 9 | salina cruz
# Processing Record 1 of Set 9 | lubao
# Processing Record 1 of Set 9 | hithadhoo
# Processing Record 1 of Set 9 | portel
# Processing Record 1 of Set 9 | viedma
# Processing Record 1 of Set 9 | alo
# Processing Record 1 of Set 9 | skutskar
# City not found. Skipping...
# Processing Record 1 of Set 9 | touros
# Processing Record 1 of Set 9 | kodinsk
# Processing Record 1 of Set 9 | rongelap
# Processing Record 1 of Set 9 | pokhara
# Processing Record 1 of Set 9 | mata-utu
# Processing Record 1 of Set 9 | mamadysh
# Processing Record 1 of Set 9 | isabela
# Processing Record 1 of Set 9 | cooma
# Processing Record 1 of Set 9 | mingora
# Processing Record 1 of Set 9 | big spring
# Processing Record 1 of Set 9 | impfondo
# Processing Record 1 of Set 9 | ambalangoda
# Processing Record 1 of Set 9 | boda
# Processing Record 1 of Set 9 | kelibia
# Processing Record 1 of Set 9 | kembe
# Processing Record 1 of Set 9 | celso ramos
# Processing Record 1 of Set 9 | al ghayzah
# Processing Record 1 of Set 9 | kapa'a
# Processing Record 1 of Set 9 | codrington
# Processing Record 1 of Set 9 | laurel
# Processing Record 1 of Set 9 | yanbu
# Processing Record 1 of Set 9 | alice
# Processing Record 1 of Set 9 | el granada
# Processing Record 1 of Set 9 | namtsy
# Processing Record 1 of Set 9 | san antonio de pale
# Processing Record 1 of Set 9 | sumenep
# Processing Record 1 of Set 9 | cabo san lucas
# Processing Record 1 of Set 9 | coracora
# Processing Record 1 of Set 9 | rzhanitsa
# Processing Record 1 of Set 9 | san rafael del sur
# Processing Record 1 of Set 9 | westport
# Processing Record 0 of Set 10 | malvan
# Processing Record 1 of Set 10 | amos
# Processing Record 1 of Set 10 | holyhead
# Processing Record 1 of Set 10 | koulamoutou
# Processing Record 1 of Set 10 | es castell
# Processing Record 1 of Set 10 | barjora
# Processing Record 1 of Set 10 | jayapura
# Processing Record 1 of Set 10 | bliss corner
# Processing Record 1 of Set 10 | souillac
# Processing Record 1 of Set 10 | fort mcmurray
# Processing Record 1 of Set 10 | mhamid
# Processing Record 1 of Set 10 | berbesti
# Processing Record 1 of Set 10 | chongwe
# Processing Record 1 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 1 of Set 10 | mount pearl
# Processing Record 1 of Set 10 | vila velha
# Processing Record 1 of Set 10 | sorel-tracy
# Processing Record 1 of Set 10 | nandyal
# Processing Record 1 of Set 10 | laguna
# Processing Record 1 of Set 10 | ingeniero jacobacci
# Processing Record 1 of Set 10 | fontenay-le-comte
# Processing Record 1 of Set 10 | mejit
# Processing Record 1 of Set 10 | canton
# Processing Record 1 of Set 10 | whitburn
# Processing Record 1 of Set 10 | santiago de cao
# Processing Record 1 of Set 10 | kalymnos
# Processing Record 1 of Set 10 | ghadamis
# Processing Record 1 of Set 10 | port alfred
# Processing Record 1 of Set 10 | vicuna mackenna
# Processing Record 1 of Set 10 | lae
# Processing Record 1 of Set 10 | weihai
# Processing Record 1 of Set 10 | rikaze
# Processing Record 1 of Set 10 | santa cruz
# Processing Record 1 of Set 10 | le port
# Processing Record 1 of Set 10 | burutu
# Processing Record 1 of Set 10 | rizhao
# Processing Record 1 of Set 10 | angra dos reis
# Processing Record 1 of Set 10 | patacamaya
# Processing Record 1 of Set 10 | kendari
# Processing Record 1 of Set 10 | kudahuvadhoo
# Processing Record 1 of Set 10 | sierra grande
# Processing Record 1 of Set 10 | plettenberg bay
# Processing Record 1 of Set 10 | royan
# Processing Record 1 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 1 of Set 10 | fort bragg
# Processing Record 1 of Set 10 | port douglas
# Processing Record 1 of Set 10 | nishinoomote
# Processing Record 1 of Set 10 | yorkton
# Processing Record 1 of Set 10 | bodaybo
# Processing Record 1 of Set 10 | zaragoza
# Processing Record 0 of Set 11 | longavi
# Processing Record 1 of Set 11 | mil'kovo
# Processing Record 1 of Set 11 | santa marta
# Processing Record 1 of Set 11 | val-d'or
# Processing Record 1 of Set 11 | estrela
# Processing Record 1 of Set 11 | strezhevoy
# Processing Record 1 of Set 11 | tuy hoa
# Processing Record 1 of Set 11 | kitimat
# Processing Record 1 of Set 11 | caleta de carquin
# Processing Record 1 of Set 11 | remire-montjoly
# Processing Record 1 of Set 11 | atherton
# Processing Record 1 of Set 11 | fangshan
# Processing Record 1 of Set 11 | egilsstadir
# Processing Record 1 of Set 11 | katima mulilo
# Processing Record 1 of Set 11 | shenkursk
# Processing Record 1 of Set 11 | ouadda
# Processing Record 1 of Set 11 | la paz
# Processing Record 1 of Set 11 | taman'
# Processing Record 1 of Set 11 | fortaleza
# Processing Record 1 of Set 11 | palmira
# Processing Record 1 of Set 11 | fort st. john
# Processing Record 1 of Set 11 | horta
# Processing Record 1 of Set 11 | weining
# Processing Record 1 of Set 11 | sarh
# Processing Record 1 of Set 11 | sao vicente
# Processing Record 1 of Set 11 | kzyltu
# Processing Record 1 of Set 11 | zaozersk
# Processing Record 1 of Set 11 | smithers
# Processing Record 1 of Set 11 | rayachoti
# Processing Record 1 of Set 11 | broken hill
# Processing Record 1 of Set 11 | belokurikha
# Processing Record 1 of Set 11 | mushie
# Processing Record 1 of Set 11 | witbank
# Processing Record 1 of Set 11 | port hedland
# Processing Record 1 of Set 11 | hammerfest
# Processing Record 1 of Set 11 | trebinje
# Processing Record 1 of Set 11 | strzelin
# Processing Record 1 of Set 11 | gebeit
# Processing Record 1 of Set 11 | hilo
# Processing Record 1 of Set 11 | shubarkuduk
# Processing Record 1 of Set 11 | arawa
# Processing Record 1 of Set 11 | meulaboh
# Processing Record 1 of Set 11 | mildura
# Processing Record 1 of Set 11 | olhao
# Processing Record 1 of Set 11 | vail
# Processing Record 1 of Set 11 | sao gabriel da cachoeira
# Processing Record 1 of Set 11 | kenora
# Processing Record 1 of Set 11 | mormugao
# Processing Record 1 of Set 11 | kuta
# Processing Record 1 of Set 11 | axim
# Processing Record 0 of Set 12 | nova vicosa
# Processing Record 1 of Set 12 | rosetta
# Processing Record 1 of Set 12 | tidjikja
# Processing Record 1 of Set 12 | beyneu
# Processing Record 1 of Set 12 | casper
# Processing Record 1 of Set 12 | faya-largeau
# Processing Record 1 of Set 12 | bougouni
# Processing Record 1 of Set 12 | irymple
# Processing Record 1 of Set 12 | kurchatov
# Processing Record 1 of Set 12 | wainwright
# Processing Record 1 of Set 12 | atlantic
# Processing Record 1 of Set 12 | puerto wilches
# Processing Record 1 of Set 12 | mugia
# Processing Record 1 of Set 12 | monrovia
# Processing Record 1 of Set 12 | inarajan village
# Processing Record 1 of Set 12 | kapuskasing
# Processing Record 1 of Set 12 | malinyi
# Processing Record 1 of Set 12 | rukungiri
# Processing Record 1 of Set 12 | portage la prairie
# Processing Record 1 of Set 12 | manokwari
# Processing Record 1 of Set 12 | dunedin
# Processing Record 1 of Set 12 | al kharj
# Processing Record 1 of Set 12 | timmins
# Processing Record 1 of Set 12 | comandante fontana
# Processing Record 1 of Set 12 | papao
# Processing Record 1 of Set 12 | grand falls-windsor
# Processing Record 1 of Set 12 | al kharijah
# Processing Record 1 of Set 12 | itamaraca
# Processing Record 1 of Set 12 | loch garman
# Processing Record 1 of Set 12 | gaigeturi
# Processing Record 1 of Set 12 | hauterive
# Processing Record 1 of Set 12 | koupela
# Processing Record 1 of Set 12 | severnoye
# Processing Record 1 of Set 12 | newman
# Processing Record 1 of Set 12 | vokhtoga
# Processing Record 1 of Set 12 | boali
# Processing Record 1 of Set 12 | ceadir-lunga
# Processing Record 1 of Set 12 | soroti
# Processing Record 1 of Set 12 | pudozh
# Processing Record 1 of Set 12 | sabha
# Processing Record 1 of Set 12 | bamboo flat
# Processing Record 1 of Set 12 | kupang
# Processing Record 1 of Set 12 | peterhead
# Processing Record 1 of Set 12 | kourou
# Processing Record 1 of Set 12 | selfoss
# Processing Record 1 of Set 12 | ginir
# Processing Record 1 of Set 12 | garhwa
# Processing Record 1 of Set 12 | barreirinhas
# Processing Record 1 of Set 12 | benguela
# Processing Record 1 of Set 12 | yreka
# Processing Record 0 of Set 13 | bandar lampung
# Processing Record 1 of Set 13 | yakeshi
# Processing Record 1 of Set 13 | madalena
# Processing Record 1 of Set 13 | pluzine
# City not found. Skipping...
# Processing Record 1 of Set 13 | smara
# Processing Record 1 of Set 13 | kalamata
# Processing Record 1 of Set 13 | dongsheng
# Processing Record 1 of Set 13 | lensk
# Processing Record 1 of Set 13 | moyynkum
# Processing Record 1 of Set 13 | muli
# Processing Record 1 of Set 13 | amalapuram
# Processing Record 1 of Set 13 | kuching
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          587
# Lat           587
# Lng           587
# Max Temp      587
# Humidity      587
# Cloudiness    587
# Wind Speed    587
# Country       587
# Date          587
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Olonkinbyen  70.9221   -8.7187     19.40        58          40
# 1              Ushuaia -54.8000  -68.3000     51.46        54          40
# 2  Fale old settlement  -9.3852 -171.2468     81.73        76          75
# 3            Grytviken -54.2811  -36.5092     41.88        82         100
# 4    Saint Paul Harbor  57.7900 -152.4072     27.91        69          75
#
#    Wind Speed Country        Date
# 0       18.59      SJ  1732906145
# 1       32.21      AR  1732906146
# 2       15.68      TK  1732906147
# 3        9.73      GS  1732906149
# 4       11.50      US  1732906150

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                Olonkinbyen  70.9221   -8.7187     19.40        58
# 1                    Ushuaia -54.8000  -68.3000     51.46        54
# 2        Fale old settlement  -9.3852 -171.2468     81.73        76
# 3                  Grytviken -54.2811  -36.5092     41.88        82
# 4          Saint Paul Harbor  57.7900 -152.4072     27.91        69
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40       18.59      SJ  1732906145
# 1                40       32.21      AR  1732906146
# 2                75       15.68      TK  1732906147
# 3               100        9.73      GS  1732906149
# 4                75       11.50      US  1732906150

# %%
#Data Cleaning Dates
city_data_df["Date"] = pd.to_datetime(city_data_df.Date * 1e9)
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                Olonkinbyen  70.9221   -8.7187     19.40        58
# 1                    Ushuaia -54.8000  -68.3000     51.46        54
# 2        Fale old settlement  -9.3852 -171.2468     81.73        76
# 3                  Grytviken -54.2811  -36.5092     41.88        82
# 4          Saint Paul Harbor  57.7900 -152.4072     27.91        69
#
#          Cloudiness  Wind Speed Country                Date
# City_ID
# 0                40       18.59      SJ 2024-11-29 18:49:05
# 1                40       32.21      AR 2024-11-29 18:49:06
# 2                75       15.68      TK 2024-11-29 18:49:07
# 3               100        9.73      GS 2024-11-29 18:49:09
# 4                75       11.50      US 2024-11-29 18:49:10

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
 # Build scatter plot for latitude vs. temperature

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.scatter(city_data_df.Lat, city_data_df["Max Temp"], color="turquoise", edgecolor="black", s=200)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Latitude", fontfamily="Arial", fontsize=12)
plt.ylabel("Temperature", fontfamily="Arial", fontsize=12)
plt.title("Latitude vs Temperature", fontweight="bold", fontsize=16, fontfamily="Arial")

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.75)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
 # Build scatter plot for latitude vs. humidity

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.scatter(city_data_df.Lat, city_data_df["Humidity"], color="turquoise", edgecolor="black", s=200)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Latitude", fontfamily="Arial", fontsize=12)
plt.ylabel("Humidity", fontfamily="Arial", fontsize=12)
plt.title("Latitude vs Humidity", fontweight="bold", fontsize=16, fontfamily="Arial")

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.75)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
 # Build scatter plot for latitude vs. cloudiness

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.scatter(city_data_df.Lat, city_data_df["Cloudiness"], color="turquoise", edgecolor="black", s=200)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Latitude", fontfamily="Arial", fontsize=12)
plt.ylabel("Cloudiness", fontfamily="Arial", fontsize=12)
plt.title("Latitude vs Cloudiness", fontweight="bold", fontsize=16, fontfamily="Arial")

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.75)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
 # Build scatter plot for latitude vs. wind speed

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.scatter(city_data_df.Lat, city_data_df["Wind Speed"], color="turquoise", edgecolor="black", s=200)

# Customizations

# Change colors
# Add in reference lines
# Add Labels/Title
plt.xlabel("Latitude", fontfamily="Arial", fontsize=12)
plt.ylabel("Wind Speed", fontfamily="Arial", fontsize=12)
plt.title("Latitude vs Wind Speed", fontweight="bold", fontsize=16, fontfamily="Arial")

# Add in a background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.75)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
 # Define a function to create Linear Regression plots

def do_regression_plot(x_values, y_values, x_label, y_label, annotation):  
    # do regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept # these are the points/predictions
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    print(rvalue)
    print(line_eq)

    # Change Canvas Size
    plt.figure(figsize=(12, 6))
    
    # Create a basic plot
    plt.scatter(x_values, y_values, color="magenta", edgecolor="black", s=200)
    plt.plot(x_values, regress_values, color="black", linewidth=6) # the regression line
    
    # Customizations
    
    # Change colors
    # Add in reference lines
    # Add Labels/Title
    plt.xlabel(x_label, fontfamily="Arial", fontsize=12)
    plt.ylabel(y_label, fontfamily="Arial", fontsize=12)
    plt.title(f"{x_label} vs {y_label}", fontweight="bold", fontsize=16, fontfamily="Arial")
    
    # Add in a background grid
    plt.grid(linestyle="--", color="lightgrey", alpha=0.75)
    
    # Annotate
    plt.annotate(line_eq, annotation, fontsize=15, color="black")
    
    # Show/Save the Graph
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df.Lat >= 0].reset_index(drop=True)

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Olonkinbyen  70.9221   -8.7187     19.40        58          40
# 1  Saint Paul Harbor  57.7900 -152.4072     27.91        69          75
# 2      Haiku-Pauwela  20.9219 -156.3051     76.05        81          25
# 3           Ironwood  46.4547  -90.1710     16.61        86         100
# 4             Bethel  41.3712  -73.4140     43.93        65          40
#
#    Wind Speed Country                Date
# 0       18.59      SJ 2024-11-29 18:49:05
# 1       11.50      US 2024-11-29 18:49:10
# 2       11.99      US 2024-11-29 18:49:11
# 3       16.11      US 2024-11-29 18:45:02
# 4        4.61      US 2024-11-29 18:49:14

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df.Lat < 0].reset_index(drop=True)

# Display sample data
southern_hemi_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                      Ushuaia -54.8000  -68.3000     51.46        54
# 1          Fale old settlement  -9.3852 -171.2468     81.73        76
# 2                    Grytviken -54.2811  -36.5092     41.88        82
# 3  Edinburgh of the Seven Seas -37.0676  -12.3116     60.91        90
# 4                     Lüderitz -26.6481   15.1594     66.15        65
#
#    Cloudiness  Wind Speed Country                Date
# 0          40       32.21      AR 2024-11-29 18:49:06
# 1          75       15.68      TK 2024-11-29 18:49:07
# 2         100        9.73      GS 2024-11-29 18:49:09
# 3         100       14.16      SH 2024-11-29 18:49:13
# 4           0       14.58     NaN 2024-11-29 18:49:19

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temperature"
annotation = (5, 5)
do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# -0.8633836887011176
# y = -1.17x + 89.96

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df.Lat
y_values = southern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temperature"
annotation = (-30, 45)
do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.6674028628641986
# y = 0.53x + 84.73

# %% [markdown]
# **Discussion about the linear relationship:** Latitude has a positive coorelation in the Southern Hemisphere with Max Temperature; where in the Northern Hemisphere it has a strong negative coorelation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df["Humidity"]
x_label = "Latitude"
y_label = "Humidity"
annotation = (60, 15)
do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.32787328960530854
# y = 0.36x + 59.0

# %%
# Southern Hemisphere
x_values = southern_hemi_df.Lat
y_values = southern_hemi_df["Humidity"]
x_label = "Latitude"
y_label = "Humidity"
annotation = (-50, 15)
do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.18276852530149004
# y = 0.28x + 77.75

# %% [markdown]
# **Discussion about the linear relationship:** Latitude has a positive coorelation in both the Northern and Southern Hemispheres with humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df["Cloudiness"]
x_label = "Latitude"
y_label = "Cloudiness"
annotation = (60, 15)
do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.15889544656653
# y = 0.33x + 47.31

# %%
# Southern Hemisphere
x_values = southern_hemi_df.Lat
y_values = southern_hemi_df["Cloudiness"]
x_label = "Latitude"
y_label = "Cloudiness"
annotation = (-40, 65)
do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.20277476110866363
# y = 0.6x + 73.52

# %% [markdown]
# **Discussion about the linear relationship:** There is a stronger positive coorelation in the Northern Hemisphere between Latitude and Cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df.Lat
y_values = northern_hemi_df["Wind Speed"]
x_label = "Latitude"
y_label = "Wind Speed"
annotation = (10, 30)
do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# 0.09392037085537422
# y = 0.03x + 7.41

# %%
# Southern Hemisphere
x_values = southern_hemi_df.Lat
y_values = southern_hemi_df["Wind Speed"]
x_label = "Latitude"
y_label = "Wind Speed"
annotation = (-20, 30)
do_regression_plot(x_values, y_values, x_label, y_label, annotation)
# Out:
# -0.19153280712884538
# y = -0.08x + 6.76

# %% [markdown]
# **Discussion about the linear relationship:** The Northern Hemisphere has a strong positive coorelation; however the Southern Hemisphere has a strong negative coorelation.
